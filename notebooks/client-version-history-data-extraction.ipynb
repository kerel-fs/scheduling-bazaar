# %% [markdown]
# # Client Version History

# %% [markdown]
# ## Investigate the Observations Database created by the scheduling-bazaar scripts.

# %%
# %load_ext sql

# %%
# %sql sqlite:////mnt/home/c4/satnogs/data/all/observations.db

# %%
# %%sql
# PRAGMA table_info([observations]);
# Out:
#  * sqlite:////mnt/home/c4/satnogs/data/all/observations.db
# Done.
#  * sqlite:////mnt/home/c4/satnogs/data/all/observations.db
# Done.

# %%
# %%sql
# SELECT
#     ground_station,
#     station_name,
#     COUNT(id) as count
# FROM observations
# WHERE
#     start >= '2023-04-04' AND
#     start < '2023-04-05'
# GROUP BY ground_station
# ORDER BY count DESC
# LIMIT 1000;

# %%
print(f'There have been {len(_)} active stations on 2023-04-04.')

# %%
# %%sql
# SELECT
#     status,
#     COUNT(id) as count
# FROM observations
# WHERE
#     start >= '2023-04-04' AND
#     start < '2023-04-05'
# GROUP BY status
# LIMIT 1000;

# %%
# %%sql
# SELECT
#     client_version,
#     COUNT(1) as count
# FROM observations
# WHERE
#     start >= '2023-04-04' AND
#     start < '2023-04-05' AND
#     status == 'good'
# GROUP BY client_version;

# %%
versions = {}
versions['2023-04-04'] = _

# %%
# %%sql
# SELECT
#     client_version,
#     ground_station,
#     station_name
# FROM observations
# WHERE
#     start >= '2023-01-04' AND
#     start < '2023-01-05' AND
#     status == 'good'
# GROUP BY ground_station;

# %% [markdown]
# ## Sample client version of each active station for one day of the month

# %%
import sqlite3
from collections import defaultdict
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
import pytz

# %%
connection = sqlite3.connect("/mnt/home/c4/satnogs/data/all/observations.db")
cursor = connection.cursor()

# %%
statement = """
SELECT
    client_version,
    ground_station,
    station_name
FROM observations
WHERE
    start >= '{}' AND
    start < '{}' AND
    status == 'good'
GROUP BY ground_station;
"""

dates = [datetime(2020, i, 4) for i in range(8,12)]
dates.extend([datetime(2021, i, 4) for i in range(1,12)])
dates.extend([datetime(2022, i, 4) for i in range(1,12)])
dates.extend([datetime(2023, 1, 4),
              datetime(2023, 2, 4),
              datetime(2023, 3, 4),
              datetime(2023, 4, 4)])

version_history = defaultdict(dict)

for date in dates:
    date2 = date + timedelta(days=1)
    rows = cursor.execute(statement.format(date.strftime('%Y-%m-%d'), date2.strftime('%Y-%m-%d'))).fetchall()
    versions = defaultdict(int)
    for entry in rows:
        versions[entry[0]] += 1

    version_history[date] = versions

df = pd.DataFrame(version_history)

version_history
# Out:
# defaultdict(dict,
#             {datetime.datetime(2020, 8, 4, 0, 0): defaultdict(int,
#                          {'1.0': 15,
#                           '1.3.4+3.gbf82932': 2,
#                           '1.3.2': 33,
#                           '1.3.1': 43,
#                           '1.3.4': 77,
#                           '0.9': 27,
#                           '1.2': 8,
#                           '1.3.1+11.g3e0cfc3.dirty': 2,
#                           '1.1.2': 5,
#                           '0.8': 4,
#                           '0.7': 4,
#                           '0.9.1': 8,
#                           '1.3.2+2.ge5f003c': 1,
#                           '': 3,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.3.4+3.gbf82932.dirty': 1,
#                           '1.1': 1,
#                           '1.3.1+4.gddef9bf': 1}),
#              datetime.datetime(2020, 9, 4, 0, 0): defaultdict(int,
#                          {'1.3.4': 102,
#                           '1.3.4+4.g8fece37': 1,
#                           '1.3.2': 25,
#                           '0.9': 25,
#                           '1.3.1': 37,
#                           '1.3.1+11.g3e0cfc3.dirty': 2,
#                           '0.8': 5,
#                           '1.1.2': 5,
#                           '0.7': 3,
#                           '0.9.1': 7,
#                           '1.3.2+2.ge5f003c': 2,
#                           '1.2': 6,
#                           '0.3+271.g0bb7196': 1,
#                           '1.0': 11,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.1': 1,
#                           '1.3.4+14.g9e13177': 1,
#                           '1.3.1+4.gddef9bf': 1,
#                           '1.3.4+0.g1f87ae3.dirty': 1,
#                           '': 1}),
#              datetime.datetime(2020, 10, 4, 0, 0): defaultdict(int,
#                          {'1.0': 12,
#                           '1.3.4': 125,
#                           '0.9': 23,
#                           '1.3.1': 31,
#                           '1.3.1+40.gc648250.dirty': 2,
#                           '0.8': 6,
#                           '1.3.2': 13,
#                           '': 4,
#                           '1.1.2': 4,
#                           '0.7': 2,
#                           '1.2': 7,
#                           '0.9.1': 6,
#                           '1.3.4-blackmensa': 2,
#                           '0.3+271.g0bb7196': 1,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.1': 2,
#                           '1.3.4+0.g1f87ae3.dirty': 1,
#                           '1.3.4+22.g1437374': 1}),
#              datetime.datetime(2020, 11, 4, 0, 0): defaultdict(int,
#                          {'1.3.4': 52,
#                           '1.4+4.g6a64c42': 1,
#                           '1.4': 73,
#                           '1.0': 9,
#                           '0.9': 18,
#                           '1.3.1': 18,
#                           '1.3.1+40.gc648250.dirty': 2,
#                           '1.3.2': 13,
#                           '0.8': 6,
#                           '1.1.2': 3,
#                           '0.7': 3,
#                           '1.3.4-blackmensa': 2,
#                           '1.2': 4,
#                           '0.9.1': 4,
#                           '0.3+271.g0bb7196': 1,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.1': 1,
#                           '': 2,
#                           '1.3.4+17.gcc74378': 1,
#                           '1.4+4.g6a64c42.dirty': 1,
#                           '1.3.4+0.g1f87ae3.dirty': 1,
#                           '1.3.4+22.g1437374': 1}),
#              datetime.datetime(2021, 1, 4, 0, 0): defaultdict(int,
#                          {'1.4': 135,
#                           '1.0': 9,
#                           '1.3.4': 24,
#                           '1.4+6.g1020354.dirty': 4,
#                           '1.3.1': 14,
#                           '1.3.2': 7,
#                           '0.8': 3,
#                           '1.1.2': 3,
#                           '0.9': 15,
#                           '0.7': 2,
#                           '1.4+6.g1020354': 9,
#                           '0.9.1': 4,
#                           '1.3.4-blackmensa': 2,
#                           '': 4,
#                           '1.4+7.g278832a': 1,
#                           '1.3.4+17.gcc74378': 1,
#                           '1.2': 1,
#                           '1.4+12.gf1c2157': 1,
#                           '1.1': 1,
#                           '1.4+8.gb9e3528': 1,
#                           '1.4+4.g6a64c42.dirty': 1,
#                           '1.4+8.g3dd402e': 2,
#                           '1.4+7.gb44baa8': 1}),
#              datetime.datetime(2021, 2, 4, 0, 0): defaultdict(int,
#                          {'1.4': 137,
#                           '1.4+8.g3dd402e': 3,
#                           '1.0': 9,
#                           '1.4+6.g1020354.dirty': 4,
#                           '1.3.4': 20,
#                           '1.3.1': 13,
#                           '0.8': 4,
#                           '1.1.2': 2,
#                           '0.7': 2,
#                           '1.3.2': 6,
#                           '1.4+6.g1020354': 3,
#                           '0.9': 14,
#                           '0.9.1': 4,
#                           '1.4-blackmensa+9.g46fb5d1': 1,
#                           '1.4+7.g278832a': 1,
#                           '1.4+9.g060844c': 1,
#                           '1.2': 1,
#                           '': 1,
#                           '1.1': 1,
#                           '1.4+8.gb9e3528': 5,
#                           '1.4+4.g6a64c42.dirty': 1}),
#              datetime.datetime(2021, 3, 4, 0, 0): defaultdict(int,
#                          {'1.4': 142,
#                           '1.4+8.g3dd402e': 2,
#                           '1.0': 8,
#                           '1.4+6.g1020354.dirty': 3,
#                           '1.3.4': 16,
#                           '1.3.1': 11,
#                           '0.8': 6,
#                           '1.1.2': 2,
#                           '0.9': 12,
#                           '0.7': 2,
#                           '1.3.2': 5,
#                           '1.4+6.g1020354': 4,
#                           '0.9.1': 3,
#                           '1.4-blackmensa+9.g46fb5d1': 3,
#                           '1.4+12.gf5eb4c4': 4,
#                           '': 2,
#                           '1.4+7.g278832a': 1,
#                           '1.4+9.g060844c': 3,
#                           '1.2': 1,
#                           '1.4+12.gf1c2157': 1,
#                           '1.1': 1,
#                           '1.4+8.gb9e3528': 2,
#                           '1.4+7.g5bd9e3b': 2,
#                           '1.4+9.g060844c.dirty': 2}),
#              datetime.datetime(2021, 4, 4, 0, 0): defaultdict(int,
#                          {'1.4': 167,
#                           '1.4+8.g3dd402e': 1,
#                           '1.0': 9,
#                           '1.4+6.g1020354.dirty': 2,
#                           '1.3.4': 17,
#                           '1.3.1': 8,
#                           '0.8': 5,
#                           '1.1.2': 3,
#                           '0.9': 11,
#                           '0.7': 2,
#                           '1.4+6.g1020354': 3,
#                           '0.9.1': 3,
#                           '1.4-blackmensa+9.g46fb5d1': 2,
#                           '1.4+12.gf5eb4c4': 10,
#                           '1.3.2': 4,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.2': 1,
#                           '1.1': 1,
#                           '1.4+8.gb9e3528': 1,
#                           '1.4+9.g060844c.dirty': 2,
#                           '1.4+9.g060844c': 2,
#                           '': 1}),
#              datetime.datetime(2021, 5, 4, 0, 0): defaultdict(int,
#                          {'1.4': 161,
#                           '1.4+8.g3dd402e': 1,
#                           '1.0': 7,
#                           '1.4+6.g1020354.dirty': 2,
#                           '1.3.4': 19,
#                           '1.3.1': 9,
#                           '': 4,
#                           '0.8': 3,
#                           '1.1.2': 1,
#                           '0.9': 11,
#                           '0.7': 2,
#                           '1.4+6.g1020354': 3,
#                           '0.9.1': 3,
#                           '1.4+12.gf5eb4c4': 7,
#                           '1.3.2': 4,
#                           '1.4+15.g11e6770': 1,
#                           '1.2': 1,
#                           '1.1': 1,
#                           '1.4+9.g060844c.dirty': 2,
#                           '1.4+9.g060844c': 1,
#                           '1.4-blackmensa+9.g46fb5d1': 1}),
#              datetime.datetime(2021, 6, 4, 0, 0): defaultdict(int,
#                          {'1.4': 126,
#                           '1.5': 17,
#                           '1.0': 7,
#                           '1.5.1': 17,
#                           '1.4+6.g1020354.dirty': 2,
#                           '1.3.4': 16,
#                           '1.3.1': 9,
#                           '0.8': 4,
#                           '1.1.2': 1,
#                           '0.9': 10,
#                           '0.7': 1,
#                           '1.4+6.g1020354': 1,
#                           '0.9.1': 3,
#                           '1.4-blackmensa+9.g46fb5d1': 3,
#                           '1.5.1+1.g5930d1b': 3,
#                           '1.3.2': 5,
#                           '1.0.dev+177.g0aa8d19': 1,
#                           '1.5+2.g3450ff2': 2,
#                           '1.4+12.gf5eb4c4': 2,
#                           '1.2': 1,
#                           '1.4+12.gf1c2157': 1,
#                           '1.1': 1,
#                           '': 2,
#                           '1.4+9.g060844c.dirty': 2,
#                           '1.4+9.g060844c': 1}),
#              datetime.datetime(2021, 7, 4, 0, 0): defaultdict(int,
#                          {'1.5.1': 55,
#                           '1.4': 102,
#                           '1.0': 7,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.3.4': 13,
#                           '1.3.1': 5,
#                           '0.8': 4,
#                           '1.5': 11,
#                           '1.3.2': 5,
#                           '1.1.2': 1,
#                           '0.7': 1,
#                           '1.4+6.g1020354': 1,
#                           '0.9': 10,
#                           '0.9.1': 2,
#                           '1.5.1-blackmensa': 3,
#                           '1.5.1+3.g105a238': 8,
#                           '1.5+2.g3450ff2': 2,
#                           '1.4+12.gf5eb4c4': 2,
#                           '1.2': 1,
#                           '': 3,
#                           '1.1': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.4+9.g060844c': 2,
#                           '1.5.1+2.g1e6badc': 1}),
#              datetime.datetime(2021, 8, 4, 0, 0): defaultdict(int,
#                          {'1.0': 7,
#                           '1.5': 9,
#                           '1.5.1': 66,
#                           '1.4': 73,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.3.4': 10,
#                           '1.3.1': 6,
#                           '1.3.2': 3,
#                           '0.9': 10,
#                           '1.1.2': 1,
#                           '0.8': 3,
#                           '0.7': 1,
#                           '1.4+6.g1020354': 1,
#                           '0.9.1': 1,
#                           '1.5.1-blackmensa': 2,
#                           '': 1,
#                           '1.5.1+3.g105a238': 9,
#                           '1.5+2.g3450ff2': 2,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.2': 1,
#                           '1.4+12.gf1c2157': 1,
#                           '1.1': 1,
#                           '1.4+9.g060844c': 1,
#                           '1.5.1+4.ge50902d': 1}),
#              datetime.datetime(2021, 9, 4, 0, 0): defaultdict(int,
#                          {'1.5.1': 63,
#                           '1.6': 32,
#                           '1.0': 7,
#                           '1.4': 76,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.3.4': 14,
#                           '1.3.1': 7,
#                           '1.3.2': 4,
#                           '0.9': 7,
#                           '1.1.2': 1,
#                           '0.8': 4,
#                           '0.7': 2,
#                           '1.5': 7,
#                           '0.9.1': 2,
#                           '0.3+336.gb5a8aa4': 1,
#                           '1.5.1+3.g105a238': 4,
#                           '1.5+2.g3450ff2': 2,
#                           '1.2': 1,
#                           '': 1,
#                           '1.4+12.gf1c2157': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.4+9.g060844c': 1,
#                           '1.5.1+2.g1e6badc': 1,
#                           '1.5.1+4.ge50902d': 1,
#                           '1.5.1-blackmensa': 1}),
#              datetime.datetime(2021, 10, 4, 0, 0): defaultdict(int,
#                          {'1.6': 51,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.4': 26,
#                           '0.8': 2,
#                           '1.3.1': 3,
#                           '': 2,
#                           '0.9': 2,
#                           '1.5.1': 14,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.3.4': 3,
#                           '0.9.1': 1,
#                           '1.5.1+3.g105a238': 2,
#                           '1.5.1+4.ge50902d': 1,
#                           '1.5.1-blackmensa': 1,
#                           '1.5+2.g3450ff2': 1}),
#              datetime.datetime(2021, 11, 4, 0, 0): defaultdict(int,
#                          {'1.6': 44,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.5.1': 9,
#                           '1.3.1': 3,
#                           '1.4': 24,
#                           '1.4+21.gb758d9a': 1,
#                           '1.5': 3,
#                           '0.8': 2,
#                           '1.3.2': 1,
#                           '1.3.4': 4,
#                           '0.9': 1,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.6+8.g0b8b7ec': 5,
#                           '1.0': 1,
#                           '1.5.1+4.ge50902d': 1,
#                           '1.5.1-blackmensa': 1,
#                           '1.5+2.g3450ff2': 1}),
#              datetime.datetime(2022, 1, 4, 0, 0): defaultdict(int,
#                          {'1.6': 81,
#                           '1.6+8.g0b8b7ec': 10,
#                           '1.0': 5,
#                           '1.4': 38,
#                           '1.5.1+2.g1e6badc.dirty': 1,
#                           '1.5.1': 19,
#                           '0.8': 3,
#                           '1.4+21.gb758d9a': 1,
#                           '0.9': 4,
#                           '0.7': 1,
#                           '1.5': 1,
#                           '0.9.1': 1,
#                           '0.3+336.gb5a8aa4': 1,
#                           '1.3.2': 2,
#                           '1.3.4': 6,
#                           '1.3.1': 5,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.2': 1,
#                           '1.0.dev+347.g08f5a14': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '': 1,
#                           '1.5.1-blackmensa': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 2, 4, 0, 0): defaultdict(int,
#                          {'1.6': 77,
#                           '1.7': 12,
#                           '1.5.1+2.g1e6badc.dirty': 2,
#                           '1.3.1': 4,
#                           '1.4': 28,
#                           '1.5.1': 11,
#                           '': 1,
#                           '1.7-blackmensa': 1,
#                           '1.7+0.g0b8b7ec.dirty': 2,
#                           '0.8': 2,
#                           '0.3+336.gb5a8aa4': 1,
#                           '1.3.2': 1,
#                           '0.9': 4,
#                           '1.3.4': 5,
#                           '1.0': 1,
#                           '0.9.1': 1,
#                           '1.5': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.6+8.g0b8b7ec': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 3, 4, 0, 0): defaultdict(int,
#                          {'1.6': 103,
#                           '1.6+8.g0b8b7ec': 1,
#                           '1.7': 16,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '1.5.1': 13,
#                           '1.4': 28,
#                           '0.9': 4,
#                           '0.7': 1,
#                           '0.9.1': 1,
#                           '1.7-blackmensa': 1,
#                           '1.7+0.g0b8b7ec.dirty': 1,
#                           '0.3+336.gb5a8aa4': 1,
#                           '0.8': 2,
#                           '': 3,
#                           '1.3.4': 8,
#                           '1.3.1': 4,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.0': 3,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 4, 4, 0, 0): defaultdict(int,
#                          {'1.6': 100,
#                           '1.7': 16,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '1.5.1': 8,
#                           '1.4': 24,
#                           '1.7-blackmensa': 1,
#                           '0.8': 1,
#                           '1.3.2': 1,
#                           '0.9': 3,
#                           '1.3.1': 2,
#                           '1.3.4': 5,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.2': 1,
#                           '1.5': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.5+2.g3450ff2': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 5, 4, 0, 0): defaultdict(int,
#                          {'1.6': 83,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '': 1,
#                           '1.7': 12,
#                           '1.5.1': 6,
#                           '1.7-blackmensa': 1,
#                           '0.8': 2,
#                           '1.3.2': 1,
#                           '0.9': 2,
#                           '1.4': 13,
#                           '1.3.1': 1,
#                           '1.3.4': 3,
#                           '0.9.1': 1,
#                           '1.0.dev+347.g08f5a14': 1,
#                           '1.5': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.0': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.7+1.g07f6c80': 3,
#                           '1.5+2.g3450ff2': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 6, 4, 0, 0): defaultdict(int,
#                          {'1.6': 84,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '1.7': 11,
#                           '1.4': 13,
#                           '0.9.1': 1,
#                           '1.7+1.g07f6c80': 6,
#                           '1.3.2': 1,
#                           '0.9': 3,
#                           '1.3.1': 2,
#                           '1.3.4': 3,
#                           '1.5.1': 4,
#                           '1.0': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '': 2,
#                           '1.5+2.g3450ff2': 1}),
#              datetime.datetime(2022, 7, 4, 0, 0): defaultdict(int,
#                          {'1.6': 86,
#                           '1.6+8.g0b8b7ec': 1,
#                           '0.3+336.gb5a8aa4': 2,
#                           '1.0': 4,
#                           '1.7': 12,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '1.4': 12,
#                           '0.8': 1,
#                           '0.9': 2,
#                           '1.5.1': 7,
#                           '1.7+1.g07f6c80': 6,
#                           '1.0.dev+117.gf5d083b': 1,
#                           '1.3.2': 1,
#                           '1.3.1': 1,
#                           '1.3.4': 2,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.2': 1,
#                           '0.9.1': 1}),
#              datetime.datetime(2022, 8, 4, 0, 0): defaultdict(int,
#                          {'1.6': 67,
#                           '1.6+8.g0b8b7ec': 1,
#                           '0.3+336.gb5a8aa4': 2,
#                           '1.0': 1,
#                           '1.4': 9,
#                           '1.5.1+14.g0b8b7ec.dirty': 1,
#                           '0.9': 2,
#                           '1.7': 8,
#                           '0.9.1': 1,
#                           '': 2,
#                           '1.7+1.g07f6c80': 5,
#                           '1.3.1': 2,
#                           '1.5.1': 2,
#                           '1.3.4': 1,
#                           '1.6+8.g0b8b7ec.dirty': 1}),
#              datetime.datetime(2022, 9, 4, 0, 0): defaultdict(int,
#                          {'1.6': 83,
#                           '0.3+336.gb5a8aa4': 2,
#                           '1.0': 2,
#                           '1.4': 15,
#                           '1.5.1+14.g0b8b7ec.dirty': 1,
#                           '1.7': 13,
#                           '1.5.1': 3,
#                           '0.9.1': 1,
#                           '1.7+1.g07f6c80': 5,
#                           '': 2,
#                           '1.3.1': 3,
#                           '1.3.4': 1,
#                           '1.2': 1,
#                           '1.6+7.g537d804': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.8': 2,
#                           '1.4+9.g060844c': 1}),
#              datetime.datetime(2022, 10, 4, 0, 0): defaultdict(int,
#                          {'1.8.1': 19,
#                           '1.6': 48,
#                           '1.5.1+14.g0b8b7ec.dirty': 1,
#                           '1.7': 7,
#                           '1.4': 11,
#                           '': 2,
#                           '1.7+1.g07f6c80': 3,
#                           '1.3.1': 2,
#                           '1.5.1': 2,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.5': 1,
#                           '1.4+9.g060844c.dirty': 1,
#                           '1.3.4': 1,
#                           '1.8.1+20.g04c56f1': 5,
#                           '1.8': 1,
#                           '1.7+5.ga435e96': 1,
#                           '1.8.1+18.gd10859d': 1}),
#              datetime.datetime(2022, 11, 4, 0, 0): defaultdict(int,
#                          {'1.6': 40,
#                           '1.5.1+14.g0b8b7ec.dirty': 2,
#                           '1.7': 4,
#                           '1.4': 12,
#                           '0.8': 1,
#                           '1.8.1': 30,
#                           '1.8.1+20.g04c56f1': 3,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.3.1': 1,
#                           '1.8': 2,
#                           '1.5.1': 1,
#                           '1.0': 1,
#                           '1.8.1+26.gaa33cbb': 3,
#                           '1.7+5.ga435e96': 1}),
#              datetime.datetime(2023, 1, 4, 0, 0): defaultdict(int,
#                          {'1.8.1': 57,
#                           '1.6': 64,
#                           '1.7': 5,
#                           '1.8.1+28.g5f23fe0': 8,
#                           '1.4': 18,
#                           '1.1.2': 1,
#                           '0.9': 4,
#                           '1.0': 5,
#                           '1.5.1': 4,
#                           '0.3+336.gb5a8aa4': 1,
#                           '1.8.1+27.gffccea9': 4,
#                           '': 6,
#                           '1.3.1': 3,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.2': 1,
#                           '0.9.1': 2,
#                           '1.5': 1,
#                           '1.3.4': 3,
#                           '0+unknown': 1,
#                           '1.5+2.g3450ff2': 1,
#                           '1.8': 2,
#                           '1.7+1.g07f6c80': 2,
#                           '1.7+21.g291ea16': 1}),
#              datetime.datetime(2023, 2, 4, 0, 0): defaultdict(int,
#                          {'1.8.1': 56,
#                           '1.6': 45,
#                           '1.7': 4,
#                           '1.8.1+28.g5f23fe0': 4,
#                           '1.4': 13,
#                           '1.1.2': 1,
#                           '0.8': 1,
#                           '0.9': 2,
#                           '1.5.1': 5,
#                           '0.3+336.gb5a8aa4': 1,
#                           '1.8.1+27.gffccea9': 4,
#                           '1.3.1': 3,
#                           '1.3.4': 2,
#                           '1.8': 3,
#                           '1.0': 1,
#                           '0+unknown': 2,
#                           '1.8.1+30.g1dec8ce': 1,
#                           '1.5+2.g3450ff2': 1,
#                           '1.7+21.g291ea16': 1}),
#              datetime.datetime(2023, 3, 4, 0, 0): defaultdict(int,
#                          {'1.0': 4,
#                           '1.4': 20,
#                           '1.6': 54,
#                           '1.7': 3,
#                           '1.8.1+28.g5f23fe0': 7,
#                           '1.8.1': 62,
#                           '1.1.2': 1,
#                           '0.8': 1,
#                           '0.9': 3,
#                           '1.5.1': 5,
#                           '0.9.1': 2,
#                           '1.8.1+27.gffccea9': 4,
#                           '1.3.1': 2,
#                           '1.3.4': 4,
#                           '0+unknown': 3,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.8': 3,
#                           '': 2,
#                           '1.3.2': 1,
#                           '1.5+2.g3450ff2': 1,
#                           '1.7+21.g291ea16': 1}),
#              datetime.datetime(2023, 4, 4, 0, 0): defaultdict(int,
#                          {'1.8.1': 71,
#                           '1.6': 55,
#                           '1.0': 5,
#                           '1.4': 20,
#                           '1.7': 5,
#                           '1.1.2': 1,
#                           '0.8': 1,
#                           '1.5.1': 6,
#                           '1.8.1+34.gf30cc9a': 3,
#                           '': 3,
#                           '0.9.1': 1,
#                           '1.8.1+27.gffccea9': 4,
#                           '0.9': 3,
#                           '1.3.1': 3,
#                           '1.3.4': 5,
#                           '0+unknown': 4,
#                           '1.4+12.gf5eb4c4': 1,
#                           '1.8': 3,
#                           '1.8.1+28.g5f23fe0': 1,
#                           '1.7+1.g07f6c80': 1,
#                           '1.7+21.g291ea16': 1,
#                           '1.7+13.g3964bfe': 1})})

# %%
reference_date = '2023-04-04'
threshold = 0.5

df_sorted = df.sort_values(by=reference_date, ascending=False)
df_short = df_sorted[df_sorted[reference_date].rank(pct=True) > threshold]

# Hack....
df_others_row = pd.DataFrame(df_sorted[df_sorted.rank(pct=True) <= threshold].sum().transpose(), columns=['others']).transpose()

df_short = pd.concat([df_short, df_others_row])
df_short
# Out:
#                    2020-08-04  2020-09-04  2020-10-04  2020-11-04  2021-01-04
# 1.8.1                     NaN         NaN         NaN         NaN         NaN  \
# 1.6                       NaN         NaN         NaN         NaN         NaN
# 1.4                       NaN         NaN         NaN        73.0       135.0
# 1.5.1                     NaN         NaN         NaN         NaN         NaN
# 1.7                       NaN         NaN         NaN         NaN         NaN
# 1.0                      15.0        11.0        12.0         9.0         9.0
# 1.3.4                    77.0       102.0       125.0        52.0        24.0
# 1.8.1+27.gffccea9         NaN         NaN         NaN         NaN         NaN
# 0+unknown                 NaN         NaN         NaN         NaN         NaN
# others                   12.0        12.0        12.0        14.0        14.0
#
#                    2021-02-04  2021-03-04  2021-04-04  2021-05-04  2021-06-04
# 1.8.1                     NaN         NaN         NaN         NaN         NaN  \
# 1.6                       NaN         NaN         NaN         NaN         NaN
# 1.4                     137.0       142.0       167.0       161.0       126.0
# 1.5.1                     NaN         NaN         NaN         NaN        17.0
# 1.7                       NaN         NaN         NaN         NaN         NaN
# 1.0                       9.0         8.0         9.0         7.0         7.0
# 1.3.4                    20.0        16.0        17.0        19.0        16.0
# 1.8.1+27.gffccea9         NaN         NaN         NaN         NaN         NaN
# 0+unknown                 NaN         NaN         NaN         NaN         NaN
# others                   17.0        18.0        16.0        13.0        18.0
#
#                    ...  2022-06-04  2022-07-04  2022-08-04  2022-09-04
# 1.8.1              ...         NaN         NaN         NaN         NaN  \
# 1.6                ...        84.0        86.0        67.0        83.0
# 1.4                ...        13.0        12.0         9.0        15.0
# 1.5.1              ...         4.0         7.0         2.0         3.0
# 1.7                ...        11.0        12.0         8.0        13.0
# 1.0                ...         1.0         4.0         1.0         2.0
# 1.3.4              ...         3.0         2.0         1.0         1.0
# 1.8.1+27.gffccea9  ...         NaN         NaN         NaN         NaN
# 0+unknown          ...         NaN         NaN         NaN         NaN
# others             ...        11.0         8.0         6.0         7.0
#
#                    2022-10-04  2022-11-04  2023-01-04  2023-02-04  2023-03-04
# 1.8.1                    19.0        30.0        57.0        56.0        62.0  \
# 1.6                      48.0        40.0        64.0        45.0        54.0
# 1.4                      11.0        12.0        18.0        13.0        20.0
# 1.5.1                     2.0         1.0         4.0         5.0         5.0
# 1.7                       7.0         4.0         5.0         4.0         3.0
# 1.0                       NaN         1.0         5.0         1.0         4.0
# 1.3.4                     1.0         NaN         3.0         2.0         4.0
# 1.8.1+27.gffccea9         NaN         NaN         4.0         4.0         4.0
# 0+unknown                 NaN         NaN         1.0         2.0         3.0
# others                    8.0         6.0        14.0        13.0        12.0
#
#                    2023-04-04
# 1.8.1                    71.0
# 1.6                      55.0
# 1.4                      20.0
# 1.5.1                     6.0
# 1.7                       5.0
# 1.0                       5.0
# 1.3.4                     5.0
# 1.8.1+27.gffccea9         4.0
# 0+unknown                 4.0
# others                   23.0
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Load Release dates from satnogs-client git history

# %% [markdown]
# Extract the release dates from git history with the following command:
# ```bash
# TZ=UTC0 git for-each-ref --sort=creatordate --format "%(refname), %(creatordate:iso)" refs/tags > /mnt/home/c4/satnogs/python/scheduling-bazaar/satnogs-client-releases.csv
# ```

# %%
release_dates = []
with open('../satnogs-client-releases.csv') as fdata:
    for line in fdata:
        ref, date_str = line.split(',')
        version = ref[10:]

        if '+' in date_str or '-' in date_str:
            # Handle timezones
            sign = '+' if '+' in date_str else '-'
            date_lcl, tz = date_str.strip().split(f' {sign}')
            date_str_iso = f'{date_lcl}{sign}{tz[:2]}:{tz[2:]}'
        else:
            date_str_iso = date_str.strip()

        date = datetime.fromisoformat(date_str_iso).astimezone(pytz.utc).replace(tzinfo=None)
        release_dates.append([version, date])

        # print(f'{version:9s} {date}')

df_versions = pd.DataFrame.from_records(release_dates, columns=['tag', 'release_date'], index='tag')
df_versions
# Out:
#                  release_date
# tag
# 0.1       2015-01-19 22:20:39
# v0.1      2015-01-19 22:20:39
# 0.2       2015-03-11 20:13:30
# v0.2      2015-03-11 20:13:30
# 0.2pypi   2015-03-14 18:23:30
# 0.2.1     2015-05-03 17:16:10
# v0.2.1    2015-05-03 17:16:10
# 0.2.2     2015-05-12 18:09:12
# v0.2.2    2015-05-12 18:09:12
# 0.2.2pypi 2015-05-22 20:15:45
# 0.2.3     2015-07-12 16:32:21
# v0.2.3    2015-07-12 16:32:21
# 0.2.3pypi 2015-07-12 17:00:02
# 0.2.4     2015-08-08 15:02:45
# v0.2.4    2015-08-08 15:02:45
# 0.2.4pypi 2015-08-08 15:08:07
# 0.2.5     2016-04-23 15:19:57
# v0.2.5    2016-04-23 15:19:57
# 0.3       2017-05-06 15:41:22
# 0.4       2017-08-14 21:50:01
# 0.4.1     2017-08-30 21:40:44
# 0.5       2017-09-29 17:43:54
# 0.5.1     2017-10-15 21:39:38
# 0.5.2     2017-11-03 18:38:00
# 0.5.3     2017-11-04 15:53:15
# 0.6       2018-05-04 21:04:00
# 0.6.1     2018-05-05 10:28:36
# 1.0.dev   2018-05-27 22:46:11
# 0.6.2     2018-05-27 22:54:18
# 0.7       2018-08-03 14:09:37
# 0.8       2018-11-30 17:02:37
# 0.9       2019-02-12 11:20:26
# 1.0       2019-10-12 23:39:10
# 1.1       2020-02-27 20:58:36
# 1.1.1     2020-02-28 21:04:47
# 1.1.2     2020-03-04 21:14:03
# 1.2       2020-03-21 19:02:11
# 1.3       2020-04-01 20:13:21
# 1.3.1     2020-04-01 20:55:20
# 1.3.2     2020-06-03 22:43:02
# 1.3.3     2020-07-10 08:55:41
# 1.3.4     2020-07-16 09:15:27
# 1.4       2020-10-05 17:37:00
# 1.5       2021-05-09 21:39:16
# 1.5.1     2021-05-30 19:40:20
# 1.6       2021-09-02 21:39:25
# 1.7       2022-01-07 08:29:10
# 1.8       2022-08-01 18:21:35
# 1.8.1     2022-09-09 20:09:23

# %% [markdown]
# ## Store df_short and df_versions

# %%
df_short.to_parquet('df_short.gzip')
df_versions.to_parquet('df_versions.gzip')
